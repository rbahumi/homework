# %%
import os
import tensorflow as tf

# tf.enable_eager_execution()
# tf.executing_eagerly()

import numpy as np
import pickle
import pandas as pd

# Set matplotlib environment
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 9000)
pd.options.display.max_colwidth = 9000

plt.style.use('bmh')
# %pylab inline

# Reload python module by default
# https://iqbalnaved.wordpress.com/2013/10/18/ipython-tip-reloading-modified-code/
# %load_ext autoreload
# %autoreload 2
# Out:
# /Users/rbahumi/PycharmProjects/gym/homework/hw3/hw3_venv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/rbahumi/PycharmProjects/gym/homework/hw3/hw3_venv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/rbahumi/PycharmProjects/gym/homework/hw3/hw3_venv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# ...

# %%
import os
CWD = os.getcwd().replace('notebooks', '')
os.chdir(CWD)

CWD
# Out:
# '/Users/rbahumi/PycharmProjects/gym/homework/hw3/'

# %%
from plot_dqn import *

DQN_DATA = "/Users/rbahumi/PycharmProjects/gym/homework/hw3/dqn_data"

# %% [markdown]
# # Question 1 - Vanila DQN

# %%
title_to_hdf = {"DQN: mean/best episode reward": os.path.join(DQN_DATA, 'qlearner_PongNoFrameskip-v4_double_q_False_14-08-2019_15-31-10.hdf')}
fig_title = "Atari Pong: Vanila DQN"
plot_results_graph_per_title(title_to_hdf, n_cols=1, fig_title=fig_title, axis_size=8)

# %% [markdown]
# # Question 2: DQN VS Double DQN

# %%
title_to_hdf = {"DQN lr_multiplier=1": os.path.join(DQN_DATA, 'qlearner_PongNoFrameskip-v4_double_q_False_14-08-2019_15-31-10.hdf'),
                "Double DQN lr_multiplier=1": os.path.join(DQN_DATA, "qlearner_PongNoFrameskip-v4_double_q_True_15-08-2019_05-53-16.hdf")}
fig_title = "Atari Pong: DQN VS Double DQN"
plot_results_per_metric(title_to_hdf, n_cols=2, fig_title=fig_title, axis_size=6)

# %% [markdown]
# We don't see an improvement for Double DQN.

# %% [markdown]
# # Question 3: comparing different learning rate multipliers

# %%
DQN_DATA = "/Users/rbahumi/PycharmProjects/gym/homework/hw3/dqn_data"
title_to_hdf = {
                "Double DQN lr_multiplier=1": os.path.join(DQN_DATA, "qlearner_PongNoFrameskip-v4_double_q_True_15-08-2019_05-53-16.hdf"),
                "Double DQN lr_multiplier=1.5": os.path.join(DQN_DATA, "qlearner_PongNoFrameskip-v4_double_q_True_lr_multiplier_1.5_16-08-2019_15-25-31.hdf"),
                "Double DQN lr_multiplier=2": os.path.join(DQN_DATA, "qlearner_PongNoFrameskip-v4_double_q_True_lr_multiplier_2_17-08-2019_09-10-28.hdf"),
                "Double DQN lr_multiplier=3": os.path.join(DQN_DATA, "qlearner_PongNoFrameskip-v4_double_q_True_lr_multiplier_3_18-08-2019_06-50-12.hdf"),
               }
fig_title = "Atari Pong Double DQN: different learning rate multipliers"
plot_results_per_metric(title_to_hdf, n_cols=2, fig_title=fig_title, axis_size=6)
